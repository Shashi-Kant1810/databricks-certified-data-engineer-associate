# %%
df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv",
    header=True,
    inferSchema=True,
)

# %% [markdown]
# ## Create table

# %%
# %sql
USE CATALOG quickstart_catalog;
DROP TABLE IF EXISTS quickstart_schema.users;
CREATE TABLE IF NOT EXISTS quickstart_schema.users(
  id INT,
  name STRING,
  dob DATE,
  email STRING,
  gender STRING,
  country STRING,
  region STRING,
  city STRING,
  asset INT,
  marital_status STRING
);
DESCRIBE EXTENDED quickstart_schema.users;

# %% [markdown]
# ## Load the data to table

# %%
df.write.mode("overwrite").saveAsTable("quickstart_schema.users")

# %% [markdown]
# ## Schema Enforcement
# 1. It ensures if any new column coming then it will reject the new data which doesn't match the schema
# 2. Solution - We have to use Schema Evolution

# %%
from pyspark.sql.functions import col
spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_006_new_column_education.csv",
    header=True,
    inferSchema=True,
).write.mode(
    "overwrite"
).saveAsTable(
    "quickstart_schema.users"
)

# %% [markdown]
# ## To fix this issue we have to use Schema Evolution

# %%
from pyspark.sql.functions import col
spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_006_new_column_education.csv",
    header=True,
    inferSchema=True,
).write.option("mergeSchema", "true").mode(
    "overwrite"
).saveAsTable(
    "quickstart_schema.users"
)

# %%
# %sql
describe history quickstart_schema.users;
