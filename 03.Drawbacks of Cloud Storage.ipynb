# %%
df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv",
    header=True,
    inferSchema=True,
)
df.display()

# %% [markdown]
# ## Disadvantages
# 1. No supprort for ACID transaction

# %%
df.write.format("parquet").save(
    "/Volumes/quickstart_catalog/quickstart_schema/sandbox/output_parquet"
)

# %%
df_parq = spark.read.parquet("/Volumes/quickstart_catalog/quickstart_schema/sandbox/output_parquet")
df_parq.display()

# %%
df_parq.createOrReplaceTempView("user_vw")

# %%
# %sql
UPDATE user_vw
set country = 'Bharat'
where country = 'India'

# %%
from pyspark.sql.functions import col
df.filter(col("country") == "India").write.save(
    format="parquet",
    mode="OVERWRITE",
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/output_parquet",
)
